# %%
import psycopg2
import pandas as pd 
from sqlalchemy import create_engine
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read data


engine = create_engine('postgres+psycopg2://postgres:amogh@localhost:5433/postgres')
df = pd.read_sql(sql = """select * from employees_info.employees  """, con = engine)

# %%
df.head(1)
# Out:
#    emp_no   birth_day                                         first_name  \
# 0   10001  1953-09-02  Georgi                                        ...
#
#                                            last_name  \
# 0  Facello                                       ...
#
#                                               gender   hire_date
# 0  M                                             ...  1986-06-26

# %%
df['year'] = pd.DatetimeIndex(df['hire_date']).year

# %%
sns.distplot(a = df['year'],kde=False)
plt.ylabel('Freq')
# Out:
# Text(0, 0.5, 'Freq')
